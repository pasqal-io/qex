# %% [markdown]
# # Neural XC training using KSDFTTrainer
#
# We provide a network that consists of:
#
# `init_fn` and `apply_fn`
#
# Then the network is being trained using `KSDFTTrainer`.
#
# 1. Load configuration
# 2. Load dataset
# 3. Define model
# 4. Train model

# %%
# !pip3 list
# !python -c "import jax; import jaxlib; import os; import sys; print(jax.__version__); print(jaxlib.__version__); print(os.environ.get('CUDA_VISIBLE_DEVICES')); print(jax.default_backend()); prin/t(jax.devices())"
# !nvidia-smi
# Out:
# Package                  Version     Editable project location
# ------------------------ ----------- -------------------------
# absl-py                  2.3.1
# asttokens                3.0.0
# chex                     0.1.89
# comm                     0.2.2
# contourpy                1.3.2
# cycler                   0.12.1
# debugpy                  1.8.15
# decorator                5.2.1
# einops                   0.8.1
# etils                    1.13.0
# exceptiongroup           1.3.0
# executing                2.2.0
# flax                     0.10.4
# fonttools                4.59.0
# fsspec                   2025.7.0
# h5py                     3.14.0
# horqrux                  0.9.2
# humanize                 4.12.3
# importlib_resources      6.5.2
# ipykernel                6.30.0
# ipython                  8.37.0
# jax                      0.4.38
# jax-cuda12-pjrt          0.4.38
# jax-cuda12-plugin        0.4.38
# jax-dft                  0.0.0
# jaxlib                   0.4.38
# jaxopt                   0.8.5
# jedi                     0.19.2
# jupyter_client           8.6.3
# jupyter_core             5.8.1
# kiwisolver               1.4.8
# loguru                   0.7.3
# markdown-it-py           3.0.0
# matplotlib               3.10.3
# matplotlib-inline        0.1.7
# mdurl                    0.1.2
# ml_dtypes                0.5.1
# msgpack                  1.1.1
# nanobind                 2.8.0
# nest-asyncio             1.6.0
# numpy                    2.2.6
# nvidia-cublas-cu12       12.9.1.4
# nvidia-cuda-cupti-cu12   12.9.79
# nvidia-cuda-nvcc-cu12    12.9.86
# nvidia-cuda-nvrtc-cu12   12.9.86
# nvidia-cuda-runtime-cu12 12.9.79
# nvidia-cudnn-cu12        9.11.0.98
# nvidia-cufft-cu12        11.4.1.4
# nvidia-cusolver-cu12     11.7.5.82
# nvidia-cusparse-cu12     12.5.10.65
# nvidia-nccl-cu12         2.27.6
# nvidia-nvjitlink-cu12    12.9.86
# nvidia-nvshmem-cu12      3.3.9
# opt_einsum               3.4.0
# optax                    0.2.5
# orbax-checkpoint         0.11.5
# packaging                25.0
# pandas                   2.3.1
# parso                    0.8.4
# pexpect                  4.9.0
# pillow                   11.3.0
# pip                      25.1.1
# platformdirs             4.3.8
# prompt_toolkit           3.0.51
# protobuf                 6.31.1
# psutil                   7.0.0
# ptyprocess               0.7.0
# pure_eval                0.2.3
# Pygments                 2.19.2
# pyparsing                3.2.3
# pyscf                    2.9.0
# pyscf-properties         0.1.0
# pyscfad                  0.1.10
# pyscfadlib               0.1.9
# python-dateutil          2.9.0.post0
# pytz                     2025.2
# PyYAML                   6.0.2
# pyzmq                    27.0.0
# QEX                      0.1.0       /home/isokolov/qex
# rich                     14.0.0
# scipy                    1.15.3
# seaborn                  0.13.2
# setuptools               58.1.0
# simplejson               3.20.1
# six                      1.17.0
# stack-data               0.6.3
# tensorstore              0.1.76
# toolz                    1.0.0
# tornado                  6.5.1
# tqdm                     4.67.1
# traitlets                5.14.3
# treescope                0.1.9
# typing_extensions        4.14.1
# tzdata                   2025.2
# wcwidth                  0.2.13
# zipp                     3.23.0
# Tue Jul 22 14:42:35 2025
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:BD:00.0 Off |                    0 |
# | N/A   35C    P0    54W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import jax
jax.devices()
# Out:
# [CudaDevice(id=0)]

# %%
import jax
# Set JAX to use 64-bit precision and enable detailed logging for debugging
jax.config.update("jax_enable_x64", True)

# %%
import os
import qedft
from qedft.models.networks import LocalMLP, GlobalMLP, LocalQNN
from qedft.config.config import Config
from pathlib import Path
from qedft.train.od.trainer import KSDFTTrainer

# Get project path
project_path = Path(os.path.dirname(os.path.dirname(qedft.__file__)))

# Load base configuration
config = Config(config_path=project_path / 'qedft' / 'config' / 'train_config.yaml').config
config
# Out:
# {'name': 'test',
#  'experiment_name': 'test',
#  'network_type': 'ksr',
#  'molecule_name': 'h2',
#  'molecule_names': ['h2'],
#  'dataset1': [128, 384],
#  'rng': 0,
#  'save_plot_loss': False,
#  'save_every_n': 20,
#  'activation': 'tanh',
#  'n_neurons': 513,
#  'n_layers': 2,
#  'n_qubits': 9,
#  'n_reupload_layers': 1,
#  'use_rzz_parametrized_entanglers': False,
#  'chebychev_reuploading': False,
#  'add_reversed_rzz': False,
#  'entangling_block_type': 'alternate_linear',
#  'single_qubit_rotations': ['rz', 'rx', 'rz'],
#  'use_same_parameters': False,
#  'add_negative_transform': False,
#  'wrap_with_self_interaction_layer': False,
#  'wrap_with_global_functional': False,
#  'use_correlators_in_output': False,
#  'output_operators': ['Z'],
#  'use_bias_in_output': False,
#  'max_train_steps': 10000,
#  'factr': 1.0,
#  'pgtol': 1e-14,
#  'm': 20,
#  'maxfun': 20,
#  'maxiter': 2,
#  'num_iterations': 15,
#  'ks_iter_to_ignore': 10,
#  'discount_factor': 0.9,
#  'alpha': 0.5,
#  'alpha_decay': 0.9,
#  'num_mixing_iterations': 1,
#  'density_mse_converge_tolerance': -1.0,
#  'stop_gradient_step': -1,
#  'enforce_reflection_symmetry': False,
#  'use_relative_encoding': False,
#  'num_grids': 513,
#  'use_amplitude_encoding': False,
#  'max_number_conv_layers': 100,
#  'list_qubits_per_layer': [],
#  'force_qubits_per_layer_is_kernel_width': False,
#  'feature_map_type': 'direct',
#  'final_mlp_layers': [1],
#  'dont_use_parametrized_observables': True,
#  'use_nel_as_input_with_mlp': False,
#  'nel_exc_combination_type': 'sum',
#  'nel_mlp_layers': [1],
#  'density_normalization_factor': 2.0,
#  'use_pmap_for_gpu_per_molecule': False,
#  'num_global_filters': 16,
#  'num_local_filters': 16,
#  'num_local_conv_layers': 2,
#  'ksr_activation': 'swish',
#  'ksr_minval': 0.1,
#  'ksr_maxval': 2.385345,
#  'ksr_downsample_factor': 0,
#  'use_exponential_coulomb': True,
#  'jit_loss': True,
#  'jit_neural_xc': True}

# %%
# Update with specific settings
config.update({
    'molecule_name': 'h2',
    'dataset1': [128, 384],
    'rng': 0,

    # Network architecture settings
    'network_type': 'mlp',  # or 'mlp' for local, 'mlp_ksr' for global
    'n_neurons': 128,
    'n_layers': 3,
    'activation': 'tanh',
    'density_normalization_factor': 2.0,
    'wrap_with_negative_transform': True,
    'wrap_self_interaction': True,
    'use_amplitude_encoding': False,

    # QNN settings
    'qnn_type': 'LocalQNN',  # "LocalQNN", "GlobalQNN"
    'layer_type': 'DirectQNN',  # "DirectQNN", "ChebyshevQNN", "ProductQNN"
    'map_fn': None,
    'n_qubits': 4,
    'n_layers': 4,

    # Optimizer settings
    'maxfun': 2,
    'maxiter': 2,
    'factr': 1,
    'm': 20,
    'pgtol': 1e-14
})

# %% [markdown]
# ***
# ## Training Global MLP

# %%
# Choose network type based on config
NetworkClass = GlobalMLP if config['network_type'] == 'mlp_ksr' else LocalMLP
network = NetworkClass(config)

# %%
# Initialize trainer
trainer = KSDFTTrainer(
    config_dict=config,
    network=network,
    data_path=project_path / 'data' / 'od'
)
# Out:
# 2025-07-21 15:30:47.319 | INFO     | qedft.train.od.trainer:__init__:58 - Initialized trainer with config: {'name': 'test', 'experiment_name': 'test', 'network_type': 'mlp', 'molecule_name': 'h2', 'molecule_names': ['h2'], 'dataset1': [128, 384], 'rng': 0, 'save_plot_loss': False, 'save_every_n': 20, 'activation': 'tanh', 'n_neurons': 128, 'n_layers': 4, 'n_qubits': 4, 'n_reupload_layers': 1, 'use_rzz_parametrized_entanglers': False, 'chebychev_reuploading': False, 'add_reversed_rzz': False, 'entangling_block_type': 'alternate_linear', 'single_qubit_rotations': ['rz', 'rx', 'rz'], 'use_same_parameters': False, 'add_negative_transform': False, 'wrap_with_self_interaction_layer': False, 'wrap_with_global_functional': False, 'use_correlators_in_output': False, 'output_operators': ['Z'], 'use_bias_in_output': False, 'max_train_steps': 10000, 'factr': 1, 'pgtol': 1e-14, 'm': 20, 'maxfun': 2, 'maxiter': 2, 'num_iterations': 15, 'ks_iter_to_ignore': 10, 'discount_factor': 0.9, 'alpha': 0.5, 'alpha_decay': 0.9, 'num_mixing_iterations': 1, 'density_mse_converge_tolerance': -1.0, 'stop_gradient_step': -1, 'enforce_reflection_symmetry': False, 'use_relative_encoding': False, 'num_grids': 513, 'use_amplitude_encoding': False, 'max_number_conv_layers': 100, 'list_qubits_per_layer': [], 'force_qubits_per_layer_is_kernel_width': False, 'feature_map_type': 'direct', 'final_mlp_layers': [1], 'dont_use_parametrized_observables': True, 'use_nel_as_input_with_mlp': False, 'nel_exc_combination_type': 'sum', 'nel_mlp_layers': [1], 'density_normalization_factor': 2.0, 'use_pmap_for_gpu_per_molecule': False, 'num_global_filters': 16, 'num_local_filters': 16, 'num_local_conv_layers': 2, 'ksr_activation': 'swish', 'ksr_minval': 0.1, 'ksr_maxval': 2.385345, 'ksr_downsample_factor': 0, 'use_exponential_coulomb': True, 'jit_loss': True, 'jit_neural_xc': True, 'wrap_with_negative_transform': True, 'wrap_self_interaction': True, 'qnn_type': 'LocalQNN', 'layer_type': 'DirectQNN', 'map_fn': None}

# %%
# Train model
params, loss, info = trainer.train(
    # checkpoint_path=project_path / 'tests' / 'ckpts' / 'ckpt-00001',
    checkpoint_save_dir=project_path / 'tests' / 'ckpts'
)
# Out:
# 2025-07-21 15:30:52.125 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:63 - Loading dataset for h2
# 2025-07-21 15:30:52.127 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:83 - Loading dataset from /home/isokolov/qex/data/od/h2
# 2025-07-21 15:30:52.135 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:95 - Training distances: [128, 384]
# 2025-07-21 15:30:52.135 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:101 - Number of electrons: 2
# 2025-07-21 15:30:52.136 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:102 - Grid shape: (513,)
# 2025-07-21 15:30:55.134 | INFO     | qedft.models.wrappers:wrap_network:189 - Wrapping network with self-interaction layer
# 2025-07-21 15:30:55.298 | INFO     | qedft.models.wrappers:wrap_network:197 - Wrapping network with negative transform
# 2025-07-21 15:30:55.298 | INFO     | qedft.train.od.trainer:train:108 - Initializing fresh parameters
# 2025-07-21 15:30:58.046 | INFO     | qedft.train.od.trainer:train:114 - Jitting neural_xc_energy_density_fn
# 2025-07-21 15:30:58.223 | INFO     | qedft.train.od.trainer:train:140 - Jitting loss_fn
# 2025-07-21 15:30:58.225 | INFO     | qedft.train.od.trainer:train:151 - Checkpoint save directory: /home/isokolov/qex/tests/ckpts
# 2025-07-21 15:30:58.225 | INFO     | qedft.train.od.trainer:train:173 - Optimizing with L-BFGS-B: {'maxfun': 2, 'factr': 1, 'm': 20, 'pgtol': 1e-14, 'maxiter': 2}
# 2025-07-21 15:30:58.240 | INFO     | qedft.train.od.train:_kohn_sham:116 - Jitting kohn_sham_func
# 2025-07-21 15:31:06.495 | INFO     | qedft.train.od.train:np_value_and_grad_fn:454 - step 0, loss 1.2605367479250282 in 8.265124797821045 sec
# 2025-07-21 15:31:06.497 | INFO     | qedft.train.od.train:np_value_and_grad_fn:458 - Save checkpoint /home/isokolov/qex/tests/ckpts/ckpt-00000
# 2025-07-21 15:31:06.749 | INFO     | qedft.train.od.train:np_value_and_grad_fn:454 - step 1, loss 21.977480575693523 in 0.2272944450378418 sec
# 2025-07-21 15:31:06.980 | INFO     | qedft.train.od.train:np_value_and_grad_fn:454 - step 2, loss 0.2735378201571361 in 0.2271556854248047 sec

# %%
print(f"Training completed with final loss: {loss}")
print(f"Optimization info: {info}")
print(f"Params: {params}")
print(f"Params shape: {params.shape}")
# Out:
# Training completed with final loss: 0.2735378201571361
# Optimization info: {'grad': array([ 9.96311132e-04,  4.82359757e-03, -4.19719858e-02, ...,
#         8.92079835e-03, -1.13485022e+00,  1.74519492e+00], shape=(49922,)), 'task': 'STOP: TOTAL NO. OF F,G EVALUATIONS EXCEEDS LIMIT', 'funcalls': 3, 'nit': 1, 'warnflag': 1}
# Params: [ 0.04249795  0.10944407 -0.19366582 ... -0.11298757  0.07328377
#   0.95798439]
# Params shape: (49922,)

# %% [markdown]
# ## Evaluating

# %%
states = trainer.evaluate(
    checkpoint_path=project_path / 'tests' / "ckpts" / "ckpt-00000",
    plot_distances=[128, 384],
)
# Out:
# 2025-07-21 15:31:18.590 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:63 - Loading dataset for h2
# 2025-07-21 15:31:18.591 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:83 - Loading dataset from /home/isokolov/qex/data/od/h2
# 2025-07-21 15:31:18.594 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:95 - Training distances: [128, 384]
# 2025-07-21 15:31:18.595 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:101 - Number of electrons: 2
# 2025-07-21 15:31:18.595 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:102 - Grid shape: (513,)
# 2025-07-21 15:31:18.632 | INFO     | qedft.models.wrappers:wrap_network:189 - Wrapping network with self-interaction layer
# 2025-07-21 15:31:18.633 | INFO     | qedft.models.wrappers:wrap_network:197 - Wrapping network with negative transform
# 2025-07-21 15:31:18.634 | INFO     | qedft.train.od.eval:load_model_params:102 - Loading checkpoint from /home/isokolov/qex/tests/ckpts/ckpt-00001
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 states = trainer.evaluate(
#       2     checkpoint_path=project_path / 'tests' / "ckpts" / "ckpt-00001",
#       3     plot_distances=[128, 384],
#       4 )
#
# File ~/qex/qedft/train/od/trainer.py:223, in KSDFTTrainer.evaluate(self, checkpoint_path, plot_distances, use_lda, output_path)
#     220 _, neural_xc_energy_density_fn = network
#     222 # Call the evaluation function
# --> 223 return eval_trained_model(
#     224     ckpt_path=str(checkpoint_path),
#     225     plot_distances=plot_distances,
#     226     plot_set=plot_set,
#     227     plot_initial_density=plot_initial_density,
#     228     num_electrons=dataset.num_electrons,
#     229     num_iterations=self.config.get("num_iterations", 100),
#     230     grids=grids,
#     231     neural_xc_energy_density_fn=neural_xc_energy_density_fn,
#     232     use_amplitude_encoding=self.config.get("use_amplitude_encoding", False),
#     233     use_lda=use_lda,
#     234     alpha=self.config.get("alpha", 0.5),
#     235     alpha_decay=self.config.get("alpha_decay", 0.9),
#     236     num_mixing_iterations=self.config.get("num_mixing_iterations", 2),
#     237     density_mse_converge_tolerance=self.config.get("density_mse_converge_tolerance", -1.0),
#     238     enforce_reflection_symmetry=self.config.get("enforce_reflection_symmetry", True),
#     239     output_path=output_path,
#     240 )
#
# File ~/qex/qedft/train/od/eval.py:217, in eval_trained_model(ckpt_path, plot_distances, plot_set, plot_initial_density, num_electrons, num_iterations, grids, neural_xc_energy_density_fn, use_amplitude_encoding, use_lda, alpha, alpha_decay, num_mixing_iterations, density_mse_converge_tolerance, enforce_reflection_symmetry, output_path)
#     179 """
#     180 Evaluate the trained model.
#     181
#    (...)
#     201     States of the Kohn-Sham calculation.
#     202 """
#     203 kohn_sham_eval_fn = partial(
#     204     kohn_sham,
#     205     num_electrons=num_electrons,
#    (...)
#     215     enforce_reflection_symmetry=enforce_reflection_symmetry,
#     216 )
# --> 217 states = get_states(
#     218     ckpt_path=ckpt_path,
#     219     kohn_sham_fn=kohn_sham_eval_fn,
#     220     plot_distances=plot_distances,
#     221     plot_set=plot_set,
#     222     plot_initial_density=plot_initial_density,
#     223 )
#     225 if output_path is not None:
#     226     save_states(states, output_path)
#
# File ~/qex/qedft/train/od/eval.py:127, in get_states(ckpt_path, kohn_sham_fn, plot_distances, plot_set, plot_initial_density)
#     107 def get_states(
#     108     ckpt_path: str,
#     109     kohn_sham_fn: Callable,
#    (...)
#     112     plot_initial_density: list,
#     113 ):
#     114     """
#     115     Get the states of the Kohn-Sham calculation.
#     116
#    (...)
#     125         States of the Kohn-Sham calculation.
#     126     """
# --> 127     params = load_model_params(ckpt_path)
#     128     states = []
#     130     for i in range(len(plot_distances)):
#
# File ~/qex/qedft/train/od/eval.py:103, in load_model_params(ckpt_path)
#      93 """
#      94 Load model parameters from a checkpoint file.
#      95
#    (...)
#     100     Model parameters.
#     101 """
#     102 logger.info(f"Loading checkpoint from {ckpt_path}")
# --> 103 with open(ckpt_path, "rb") as handle:
#     104     return pickle.load(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/isokolov/qex/tests/ckpts/ckpt-00001'

# %% [markdown]
# ***
# ## Training Quantum Neural Networks

# %%
# Local model
NetworkClass = LocalQNN
config['network_type'] = 'mlp'
config['use_amplitude_encoding'] = False
network = NetworkClass(config)

# Initialize trainer
trainer = KSDFTTrainer(
    config_dict=config,
    network=network,
    data_path=project_path / 'data' / 'od'
)
# Out:
# 2025-04-14 18:06:15.832 | INFO     | qedft.train.od.trainer:__init__:59 - Initialized trainer with config: {'name': 'test', 'experiment_name': 'test', 'network_type': 'mlp', 'molecule_name': 'h2', 'molecule_names': ['h2'], 'dataset1': [128, 384], 'rng': 0, 'save_plot_loss': False, 'save_every_n': 20, 'activation': 'tanh', 'n_neurons': 128, 'n_layers': 4, 'n_qubits': 4, 'n_reupload_layers': 1, 'use_rzz_parametrized_entanglers': False, 'chebychev_reuploading': False, 'add_reversed_rzz': False, 'entangling_block_type': 'alternate_linear', 'single_qubit_rotations': ['rz', 'rx', 'rz'], 'use_same_parameters': False, 'add_negative_transform': False, 'wrap_with_self_interaction_layer': False, 'wrap_with_global_functional': False, 'use_correlators_in_output': False, 'output_operators': ['Z'], 'use_bias_in_output': False, 'max_train_steps': 10000, 'factr': 1, 'pgtol': 1e-14, 'm': 20, 'maxfun': 2, 'maxiter': 2, 'num_iterations': 15, 'ks_iter_to_ignore': 10, 'discount_factor': 0.9, 'alpha': 0.5, 'alpha_decay': 0.9, 'num_mixing_iterations': 1, 'density_mse_converge_tolerance': -1.0, 'stop_gradient_step': -1, 'enforce_reflection_symmetry': False, 'use_relative_encoding': False, 'num_grids': 513, 'use_amplitude_encoding': False, 'max_number_conv_layers': 100, 'list_qubits_per_layer': [], 'force_qubits_per_layer_is_kernel_width': False, 'feature_map_type': 'direct', 'final_mlp_layers': [1], 'dont_use_parametrized_observables': True, 'use_nel_as_input_with_mlp': False, 'nel_exc_combination_type': 'sum', 'nel_mlp_layers': [1], 'density_normalization_factor': 2.0, 'use_pmap_for_gpu_per_molecule': False, 'num_global_filters': 16, 'num_local_filters': 16, 'num_local_conv_layers': 2, 'ksr_activation': 'swish', 'ksr_minval': 0.1, 'ksr_maxval': 2.385345, 'ksr_downsample_factor': 0, 'use_exponential_coulomb': True, 'jit_loss': True, 'jit_neural_xc': True, 'wrap_with_negative_transform': True, 'wrap_self_interaction': True, 'qnn_type': 'LocalQNN', 'layer_type': 'DirectQNN', 'map_fn': None}

# %%
# Train model
params, loss, info = trainer.train(
    # checkpoint_path=project_path / 'tests' / 'ckpts' / 'ckpt-00001',
    checkpoint_save_dir=project_path / 'tests' / 'ckpts'
)
# Out:
# 2025-04-14 18:06:15.837 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:63 - Loading dataset for h2
# 2025-04-14 18:06:15.838 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:83 - Loading dataset from /Users/igorsokolov/PycharmProjects/qedft/data/od/h2
# 2025-04-14 18:06:15.840 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:95 - Training distances: [128, 384]
# 2025-04-14 18:06:15.840 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:101 - Number of electrons: 2
# 2025-04-14 18:06:15.840 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:102 - Grid shape: (513,)
# 2025-04-14 18:06:16.202 | INFO     | qedft.models.quantum.quantum_models:build_qnn:682 - Building LocalQNN QNN with DirectQNN layer_type
# 2025-04-14 18:06:16.203 | INFO     | qedft.models.wrappers:wrap_network:189 - Wrapping network with self-interaction layer
# 2025-04-14 18:06:16.204 | INFO     | qedft.models.wrappers:wrap_network:197 - Wrapping network with negative transform
# 2025-04-14 18:06:16.205 | INFO     | qedft.train.od.trainer:train:109 - Initializing fresh parameters
# 2025-04-14 18:06:16.284 | INFO     | qedft.train.od.trainer:train:115 - Jitting neural_xc_energy_density_fn
# 2025-04-14 18:06:16.309 | INFO     | qedft.train.od.trainer:train:141 - Jitting loss_fn
# 2025-04-14 18:06:16.311 | INFO     | qedft.train.od.trainer:train:152 - Checkpoint save directory: /Users/igorsokolov/PycharmProjects/qedft/tests/ckpts
# 2025-04-14 18:06:16.311 | INFO     | qedft.train.od.trainer:train:174 - Optimizing with L-BFGS-B: {'maxfun': 2, 'factr': 1, 'm': 20, 'pgtol': 1e-14, 'maxiter': 2}
# 2025-04-14 18:06:16.316 | INFO     | qedft.train.od.train:_kohn_sham:115 - Jitting kohn_sham_func
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Train model
# ----> 2 params, loss, info = trainer.train(
#       3     # checkpoint_path=project_path / 'tests' / 'ckpts' / 'ckpt-00001',
#       4     checkpoint_save_dir=project_path / 'tests' / 'ckpts'
#       5 )
#
# File ~/PycharmProjects/qedft/qedft/train/od/trainer.py:175, in KSDFTTrainer.train(self, checkpoint_path, checkpoint_save_dir)
#     166 optimizer_kwargs = {
#     167     "maxfun": self.config.get("maxfun", 1000),
#     168     "factr": self.config.get("factr", 1),
#    (...)
#     171     "maxiter": self.config.get("maxiter", 1000),
#     172 }
#     174 logger.info(f"Optimizing with L-BFGS-B: {optimizer_kwargs}")
# --> 175 params, loss, info = scipy.optimize.fmin_l_bfgs_b(
#     176     training_step,
#     177     x0=np.array(flatten_init_params),
#     178     **optimizer_kwargs,
#     179 )
#     181 return params, loss, info
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:199, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     187 callback = _wrap_callback(callback)
#     188 opts = {'disp': disp,
#     189         'iprint': iprint,
#     190         'maxcor': m,
#    (...)
#     196         'callback': callback,
#     197         'maxls': maxls}
# --> 199 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     200                        **opts)
#     201 d = {'grad': res['jac'],
#     202      'task': res['message'],
#     203      'funcalls': res['nfev'],
#     204      'nit': res['nit'],
#     205      'warnflag': res['status']}
#     206 f = res['fun']
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:307, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     304     else:
#     305         iprint = disp
# --> 307 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     308                               bounds=new_bounds,
#     309                               finite_diff_rel_step=finite_diff_rel_step)
#     311 func_and_grad = sf.fun_and_grad
#     313 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_optimize.py:383, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     379     bounds = (-np.inf, np.inf)
#     381 # ScalarFunction caches. Reuse of fun(x) during grad
#     382 # calculation reduces overall function evaluations.
# --> 383 sf = ScalarFunction(fun, x0, args, grad, hess,
#     384                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     386 return sf
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_optimize.py:77, in MemoizeJac.__call__(self, x, *args)
#      75 def __call__(self, x, *args):
#      76     """ returns the function value """
# ---> 77     self._compute_if_needed(x, *args)
#      78     return self._value
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/scipy/optimize/_optimize.py:71, in MemoizeJac._compute_if_needed(self, x, *args)
#      69 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      70     self.x = np.asarray(x).copy()
# ---> 71     fg = self.fun(x, *args)
#      72     self.jac = fg[1]
#      73     self._value = fg[0]
#
# File ~/PycharmProjects/qedft/qedft/train/od/train.py:451, in create_training_step.<locals>.np_value_and_grad_fn(flatten_params)
#     449 step_time = time.time() - start_time
#     450 step = initial_checkpoint_index + len(loss_record)
# --> 451 logger.info(f"step {step}, loss {train_set_loss} in {step_time} sec")
#     453 if checkpoint_dir and len(loss_record) % save_every_n == 0:
#     454     checkpoint_path = f"{checkpoint_dir}/{ckpt_prefix}-{step:05d}"
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/jax/_src/array.py:330, in ArrayImpl.__format__(self, format_spec)
#     327 def __format__(self, format_spec):
#     328   # Simulates behavior of https://github.com/numpy/numpy/pull/9883
#     329   if self.ndim == 0:
# --> 330     return format(self._value[()], format_spec)
#     331   else:
#     332     return format(self._value, format_spec)
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/PycharmProjects/qedft/.venv_legacy/lib/python3.10/site-packages/jax/_src/array.py:629, in ArrayImpl._value(self)
#     627 if self._npy_value is None:
#     628   if self.is_fully_replicated:
# --> 629     self._npy_value = self._single_device_array_to_np_array()
#     630     self._npy_value.flags.writeable = False
#     631     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
print(f"Training completed with final loss: {loss}")
print(f"Optimization info: {info}")
print(f"Params: {params}")
print(f"Params shape: {params.shape}")
# Out:
# Training completed with final loss: 1.5183673980519223
# Optimization info: {'grad': array([-1.71702502e+00,  1.38279942e+00, -1.73077662e+00,  8.80152018e-02,
#         1.89468187e-02,  7.65675404e-02, -4.16455339e-01, -6.87734670e-02,
#        -4.16367478e-01, -1.77017195e+00,  1.40453201e+00, -1.78526662e+00,
#        -6.49569404e-01,  4.16965948e-01, -6.48556226e-01,  4.74949575e-02,
#        -1.68425865e-01,  4.74694475e-02,  6.48634315e-02,  4.82608181e-01,
#         6.90992656e-02, -6.48559069e-01,  6.45917479e-01, -6.47515901e-01,
#         1.30619078e-01,  4.60207926e-01,  1.39392388e-01,  1.03025516e-01,
#        -2.33559947e-01,  1.04589301e-01,  3.56400514e-01, -3.69753865e-05,
#         3.56650440e-01,  1.01798449e-01,  1.01815418e+00,  1.04123187e-01,
#        -3.79558758e-01,  2.52509012e-01, -3.80531982e-01, -2.73927123e-01,
#        -8.97630050e-03, -2.74366758e-01,  3.36531426e-02, -1.63257048e-01,
#         3.47760489e-02, -3.70868828e-01,  4.56596677e-01, -3.68655690e-01,
#         4.02880928e+00]), 'task': 'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT', 'funcalls': 8, 'nit': 2, 'warnflag': 1}
# Params: [-1.64784055e-01  2.22200480e-01 -1.27401062e-01  4.27677834e-02
#   9.39766833e-02 -6.94114791e-02 -1.03818036e-01 -2.56201352e-02
#  -7.55753159e-02 -1.57587673e-01  2.09826876e-01 -8.53665532e-02
#   2.90905638e-02  1.29575268e-01  4.59378102e-02 -9.88481220e-02
#  -2.38994643e-04  9.43156035e-02  5.36767932e-02  1.59742477e-01
#  -3.40543344e-02 -1.21414054e-01  1.48990148e-02 -1.14940247e-01
#   6.79194335e-02  2.01443940e-01 -3.91036340e-02  8.35759900e-02
#  -1.02983336e-01  3.79389324e-02  7.79751194e-02 -2.14306865e-02
#   3.40812191e-02  9.73142901e-02  6.26424575e-02 -6.95579070e-02
#  -3.09823630e-02  9.99703103e-02  8.73882506e-03 -5.00935782e-02
#   8.70006062e-02 -1.24043692e-01  6.92171097e-02 -9.66527660e-02
#  -6.08968095e-02 -4.75435382e-02  7.29223736e-02 -9.56859757e-02
#   1.94076586e+00]
# Params shape: (49,)

# %%
# Demo snippet

import os
import qedft
from qedft.models.networks import LocalMLP, LocalQNN
from qedft.config.config import Config
from pathlib import Path
from qedft.train.od.trainer import KSDFTTrainer
from loguru import logger

# Get project path
project_path = Path(os.path.dirname(os.path.dirname(qedft.__file__)))

# Load base configuration
config = Config(config_path=project_path / 'qedft' / 'config' / 'train_config.yaml').config

# The network object has the function `build_network` that returns (init_fn, apply_fn)
network = LocalMLP(config)

# Initialize trainer
trainer = KSDFTTrainer(
    config_dict=config,
    network=network,
    data_path=project_path / 'data' / 'od'
)

# Train model
params, loss, info = trainer.train(
    # checkpoint_path=project_path / 'tests' / 'ckpts' / 'ckpt-00001',
    checkpoint_save_dir=project_path / 'tests' / 'ckpts'
)
# Out:
# 2025-05-02 14:44:45.109 | INFO     | qedft.train.od.trainer:__init__:58 - Initialized trainer with config: {'name': 'test', 'experiment_name': 'test', 'network_type': 'ksr', 'molecule_name': 'h2', 'molecule_names': ['h2'], 'dataset1': [128, 384], 'rng': 0, 'save_plot_loss': False, 'save_every_n': 20, 'activation': 'tanh', 'n_neurons': 513, 'n_layers': 2, 'n_qubits': 9, 'n_reupload_layers': 1, 'use_rzz_parametrized_entanglers': False, 'chebychev_reuploading': False, 'add_reversed_rzz': False, 'entangling_block_type': 'alternate_linear', 'single_qubit_rotations': ['rz', 'rx', 'rz'], 'use_same_parameters': False, 'add_negative_transform': False, 'wrap_with_self_interaction_layer': False, 'wrap_with_global_functional': False, 'use_correlators_in_output': False, 'output_operators': ['Z'], 'use_bias_in_output': False, 'max_train_steps': 10000, 'factr': 1.0, 'pgtol': 1e-14, 'm': 20, 'maxfun': 20, 'maxiter': 2, 'num_iterations': 15, 'ks_iter_to_ignore': 10, 'discount_factor': 0.9, 'alpha': 0.5, 'alpha_decay': 0.9, 'num_mixing_iterations': 1, 'density_mse_converge_tolerance': -1.0, 'stop_gradient_step': -1, 'enforce_reflection_symmetry': False, 'use_relative_encoding': False, 'num_grids': 513, 'use_amplitude_encoding': False, 'max_number_conv_layers': 100, 'list_qubits_per_layer': [], 'force_qubits_per_layer_is_kernel_width': False, 'feature_map_type': 'direct', 'final_mlp_layers': [1], 'dont_use_parametrized_observables': True, 'use_nel_as_input_with_mlp': False, 'nel_exc_combination_type': 'sum', 'nel_mlp_layers': [1], 'density_normalization_factor': 2.0, 'use_pmap_for_gpu_per_molecule': False, 'num_global_filters': 16, 'num_local_filters': 16, 'num_local_conv_layers': 2, 'ksr_activation': 'swish', 'ksr_minval': 0.1, 'ksr_maxval': 2.385345, 'ksr_downsample_factor': 0, 'use_exponential_coulomb': True, 'jit_loss': True, 'jit_neural_xc': True}
# 2025-05-02 14:44:45.112 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:63 - Loading dataset for h2
# 2025-05-02 14:44:45.112 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:83 - Loading dataset from /Users/igorsokolov/PycharmProjects/qedft/data/od/h2
# 2025-05-02 14:44:45.122 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:95 - Training distances: [128, 384]
# 2025-05-02 14:44:45.124 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:101 - Number of electrons: 2
# 2025-05-02 14:44:45.124 | INFO     | qedft.data_io.dataset_loader:load_molecular_datasets:102 - Grid shape: (513,)
# 2025-05-02 14:44:45.151 | INFO     | qedft.train.od.trainer:train:108 - Initializing fresh parameters
# 2025-05-02 14:44:45.381 | INFO     | qedft.train.od.trainer:train:114 - Jitting neural_xc_energy_density_fn
# 2025-05-02 14:44:45.438 | INFO     | qedft.train.od.trainer:train:140 - Jitting loss_fn
# 2025-05-02 14:44:45.441 | INFO     | qedft.train.od.trainer:train:151 - Checkpoint save directory: /Users/igorsokolov/PycharmProjects/qedft/tests/ckpts
# 2025-05-02 14:44:45.444 | INFO     | qedft.train.od.trainer:train:173 - Optimizing with L-BFGS-B: {'maxfun': 20, 'factr': 1.0, 'm': 20, 'pgtol': 1e-14, 'maxiter': 2}
# 2025-05-02 14:44:46.057 | INFO     | qedft.train.od.train:_kohn_sham:116 - Jitting kohn_sham_func
# 2025-05-02 14:44:52.135 | INFO     | qedft.train.od.train:np_value_and_grad_fn:454 - step 0, loss 0.8011694069521917 in 1.6346240043640137 sec
# 2025-05-02 14:44:52.150 | INFO     | qedft.train.od.train:np_value_and_grad_fn:458 - Save checkpoint /Users/igorsokolov/PycharmProjects/qedft/tests/ckpts/ckpt-00000
# 2025-05-02 14:44:58.374 | INFO     | qedft.train.od.train:np_value_and_grad_fn:454 - step 1, loss 35.404150417893135 in 0.00043082237243652344 sec
# 2025-05-02 14:45:03.515 | INFO     | qedft.train.od.train:np_value_and_grad_fn:454 - step 2, loss 0.00476459493342624 in 0.0016510486602783203 sec
# 2025-05-02 14:45:07.515 | INFO     | qedft.train.od.train:np_value_and_grad_fn:454 - step 3, loss 0.004655746981241526 in 0.0007851123809814453 sec

# %% [markdown]
# # Summary
#
# This notebook demonstrates training a neural network model for Kohn-Sham DFT:
#
# 1. Sets up configuration for a global MLP model with 3 layers, 128 neurons, and tanh activation
# 2. Also sets up configuration for a local QNN model with 2 qubits, 1 layer, and DirectQNN ansatz
# 3. Initializes KSDFTTrainer with the model configuration and H2 molecule dataset
# 4. Trains the model using L-BFGS-B optimization:
#    - Loads parameters from checkpoint ckpt-00009
#    - Uses small maxfun/maxiter of 2 for testing
#    - Minimizes loss combining energy and density errors
#    - Saves checkpoints during training
#
# The trained model learns to predict the exchange-correlation functional for H2,
# with the goal of accurately reproducing DFT energies and electron densities.
